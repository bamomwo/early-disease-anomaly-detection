# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("../data/labelled/5C.csv")

# %%
data.head()
# Out:
#          session            timestamp  hr_mean     hr_std  hr_min  hr_max  \
# 0  5C_1586886626  2020-04-14 17:50:30  90.6675  20.493305   77.00  121.00
# 1  5C_1586886626  2020-04-14 17:50:40  78.9880   2.316164   74.40   81.29
# 2  5C_1586886626  2020-04-14 17:50:50  82.1080   0.637352   81.60   83.58
# 3  5C_1586886626  2020-04-14 17:51:00  86.8230   1.691036   84.28   89.47
# 4  5C_1586886712  2020-04-14 17:51:50      NaN        NaN     NaN     NaN
#
#    hr_range  temp_mean  temp_std  temp_min  ...  bvp_rise_time_mean  \
# 0     44.00   31.89600  0.080537     31.79  ...            0.264509
# 1      6.89   31.82000  0.037622     31.75  ...            0.313477
# 2      1.98   31.96200  0.097539     31.83  ...            0.260742
# 3      5.19   32.12000  0.035662     32.07  ...            0.310547
# 4       NaN   32.69875  0.014756     32.68  ...            0.363281
#
#    bvp_rise_time_std  bvp_pulse_rate  eda_acc_ratio  hr_acc_ratio  \
# ...

# %%
data[data['stress_level'] > 0]['temp_mean'].mean()
# Out:
# np.float64(28.651347865412447)

# %%
data[data['stress_level']==0]['temp_mean'].mean()
# Out:
# np.float64(32.23509132200948)
